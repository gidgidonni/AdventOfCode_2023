# %% [markdown]
# # Advent of Code
#
# ## Day 2: Cube Conundrum

# %%
import re

def line_cleaner(original_line):

    cleaned_line = original_line.replace('red','r')
    cleaned_line = cleaned_line.replace('blue','b')
    cleaned_line = cleaned_line.replace('green','g')

    return cleaned_line

with open('Day2.txt') as Day2_file:
    
    game_num = 1
    result = 0
    game_cubes = []

    for line in Day2_file:

        print(game_num)

        num_r = re.findall(r'\s[0-9]+\sr', line)
        print(num_r)
        num_b = re.findall(r'\s[0-9]+\sb', line)
        print(num_b)
        num_g = re.findall(r'\s[0-9]+\sg', line)
        print(num_g)

        r = re.findall(r'[0-9]+', str(num_r))
        print(r)
        b = re.findall(r'[0-9]+', str(num_b))
        print(b)
        g = re.findall(r'[0-9]+', str(num_g))
        print(g)

        r_numbers = [ int(x) for x in r ]
        print(r_numbers)
        b_numbers = [ int(x) for x in b ]
        print(b_numbers)
        g_numbers = [ int(x) for x in g ]
        print(g_numbers)

        r_max = max(r_numbers)
        print(r_max)
        b_max = max(b_numbers)
        print(b_max)
        g_max = max(g_numbers)
        print(g_max)

        game_cubes = [r_max, b_max, g_max]
        print(game_cubes)

        game_power = 1
        for i in game_cubes:
            game_power = game_power * i
        print(game_power)

        result += game_power
        print(result)

        game_num += 1

        print('\n')

print(result)
# Out:
# 1
# [' 7 r', ' 3 r', ' 15 r', ' 3 r', ' 11 r']
# [' 14 b', ' 2 b', ' 12 b', ' 12 b']
# [' 3 g', ' 4 g', ' 3 g', ' 2 g']
# ['7', '3', '15', '3', '11']
# ['14', '2', '12', '12']
# ['3', '4', '3', '2']
# [7, 3, 15, 3, 11]
# [14, 2, 12, 12]
# [3, 4, 3, 2]
# 15
# 14
# 4
# [15, 14, 4]
# 840
# 840
#
#
# 2
# [' 9 r', ' 8 r', ' 12 r', ' 17 r']
# [' 16 b', ' 8 b', ' 11 b']
# [' 5 g', ' 5 g', ' 8 g']
# ['9', '8', '12', '17']
# ['16', '8', '11']
# ['5', '5', '8']
# [9, 8, 12, 17]
# [16, 8, 11]
# [5, 5, 8]
# 17
# 16
# 8
# [17, 16, 8]
# 2176
# 3016
#
#
# 3
# [' 7 r', ' 12 r', ' 1 r', ' 4 r', ' 2 r']
# [' 1 b', ' 6 b', ' 2 b', ' 1 b']
# [' 8 g', ' 9 g', ' 14 g', ' 9 g', ' 8 g']
# ['7', '12', '1', '4', '2']
# ['1', '6', '2', '1']
# ['8', '9', '14', '9', '8']
# [7, 12, 1, 4, 2]
# [1, 6, 2, 1]
# [8, 9, 14, 9, 8]
# 12
# 6
# 14
# [12, 6, 14]
# 1008
# 4024
#
#
# 4
# [' 1 r', ' 1 r']
# [' 1 b', ' 1 b']
# [' 3 g', ' 2 g', ' 3 g']
# ['1', '1']
# ['1', '1']
# ['3', '2', '3']
# [1, 1]
# [1, 1]
# [3, 2, 3]
# ...
